# %%
import pandas as pd
from copy import deepcopy
from sklearn import preprocessing
import numpy as np

# %%
user_data = {
    'Gender': "female",
    'Race/Ethnicity': "group D",
    'Home_City': "Islamabad",
    'Preferred_Langauge': "English",
    'Hobby_Interest': "Gaming",
    'Budget': "Medium",
    'Fathers_Occupation': "Doctor",
    'Mothers_Occupation':  "House Wife",
    'Study_Group':  "Pre-Engrr",
    'Degree_Program':  "BSCS",
    'Matric Grade':  "A",
    'Inter Grade':  "A-",
    'Preferred_Location':  "Islamabad",
}

user_data = pd.DataFrame([user_data])

#Renaming last column
user_data.rename(columns={"Preferred_Location" : "Campus"}, inplace=True)
user_data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  Budget  \
# 0  female        group D  Islamabad            English         Gaming  Medium
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife   Pre-Engrr           BSCS
#
#   Matric Grade Inter Grade     Campus
# 0            A          A-  Islamabad

# %%
data = pd.read_csv('./CleanData.csv')
data.head()
# Out:
#    Gender Race/Ethnicity Home_City Preferred_Langauge Hobby_Interest  Budget  \
# 0  female        group B   Karachi            Punjabi        Reading    High
# 1  female        group C   Karachi               Urdu        Reading  Medium
# 2  female        group B    Lahore               Urdu         Sports  Medium
# 3    male        group A   Karachi               Urdu         Sports    High
# 4    male        group C  Peshawar               Urdu         Gaming    High
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife          CS           BSCS
# 1              Engrr         House Wife   Pre-Engrr           BSEE
# 2              Engrr         House Wife   Pre-Engrr           BSCS
# 3             Doctor         House Wife   Pre-Engrr           BSCS
# 4             Doctor         House Wife          CS           BSEE
#
#   Matric Grade Inter Grade     Campus  University
# 0           A+          A+    Karachi  FAST NUCES
# 1            B           B  Islamabad  FAST NUCES
# 2            B           A     Lahore  FAST NUCES
# 3           A+          A+  Islamabad  FAST NUCES
# 4           A+          A+   Peshawar  FAST NUCES

# %%
X = data.iloc[:, 0:13]
y = data.iloc[:, 13]

y
# Out:
# 0      FAST NUCES
# 1      FAST NUCES
# 2      FAST NUCES
# 3      FAST NUCES
# 4      FAST NUCES
#           ...
# 245       COMSATS
# 246       COMSATS
# 247       COMSATS
# 248       COMSATS
# 249       COMSATS
# Name: University, Length: 250, dtype: object

# %% [markdown]
# ### Concatinating Data

# %%
X = pd.concat([X, user_data])
X.tail()
# Out:
#      Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  \
# 246    male        group A    Sialkot            English        Nothing
# 247  female        group C    Sialkot             Pashto        Reading
# 248  female        group B     Gujrat               Urdu        Reading
# 249    male        group C    Sialkot               Urdu        Reading
# 0    female        group D  Islamabad            English         Gaming
#
#      Budget Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 246    High             Doctor             Doctor          CS            BBA
# 247    High               Army             Doctor          CS            BBA
# 248  Medium               Army             Doctor   Pre-Engrr           BSEE
# 249  Medium               Army             Doctor   Pre-Engrr           BSEE
# 0    Medium             Doctor         House Wife   Pre-Engrr           BSCS
#
#     Matric Grade Inter Grade     Campus
# 246           A+          A-     Lahore
# 247           A+          A+     Lahore
# 248           A+          A+     Lahore
# 249            B           B     Lahore
# 0              A          A-  Islamabad

# %%
X.shape
# Out:
# (251, 13)

# %% [markdown]
# ### Encoding Training Data

# %%
le = preprocessing.LabelEncoder()

gender = le.fit_transform(list(X['Gender']))
race = le.fit_transform(list(X['Race/Ethnicity']))
home_city = le.fit_transform(list(X['Home_City']))
preferred_lang = le.fit_transform(list(X['Preferred_Langauge']))
hobby_interest = le.fit_transform(list(X['Hobby_Interest']))
budget = le.fit_transform(list(X['Budget']))
F_Occ = le.fit_transform(list(X['Fathers_Occupation']))
M_Occ = le.fit_transform(list(X['Mothers_Occupation']))
study_group = le.fit_transform(list(X['Study_Group']))
degree_program = le.fit_transform(list(X['Degree_Program']))
matric_grade = le.fit_transform(list(X['Matric Grade']))
inter_grade = le.fit_transform(list(X['Inter Grade']))
campus = le.fit_transform(list(X['Campus']))

class_attribute = le.fit_transform(list(y))

X_prep = pd.DataFrame(list(zip(gender, race, home_city, preferred_lang, hobby_interest, budget, F_Occ, M_Occ, study_group,
                          degree_program, matric_grade, inter_grade, campus)), columns=['Gender', 'Race/Ethnicity', 'Home_City', 'Preferred_Langauge', 'Hobby_Interest', 'Budget', 'Fathers_Occupation', 'Mothers_Occupation', 'Study_Group', 'Degree_Program', 'Matric Grade', 'Inter Grade', 'Campus'])

y_prep = pd.DataFrame(list(class_attribute), columns=['University'])

# %%
X_prep.shape
# Out:
# (251, 13)

# %%
X_prep.tail()
# Out:
#      Gender  Race/Ethnicity  Home_City  Preferred_Langauge  Hobby_Interest  \
# 246       1               0          8                   0               1
# 247       0               2          8                   2               2
# 248       0               1          1                   4               2
# 249       1               2          8                   4               2
# 250       0               3          2                   0               0
#
#      Budget  Fathers_Occupation  Mothers_Occupation  Study_Group  \
# 246       0                   1                   0            1
# 247       0                   0                   0            1
# 248       2                   0                   0            3
# 249       2                   0                   0            3
# 250       2                   1                   1            3
#
#      Degree_Program  Matric Grade  Inter Grade  Campus
# 246               0             1            2       2
# 247               0             1            1       2
# 248               5             1            1       2
# 249               5             3            3       2
# 250               4             0            2       0

# %%
y_prep.shape
# Out:
# (250, 1)

# %%
user_data_prep = X_prep.iloc[250]
user_data_prep
# Out:
# Gender                0
# Race/Ethnicity        3
# Home_City             2
# Preferred_Langauge    0
# Hobby_Interest        0
# Budget                2
# Fathers_Occupation    1
# Mothers_Occupation    1
# Study_Group           3
# Degree_Program        4
# Matric Grade          0
# Inter Grade           2
# Campus                0
# Name: 250, dtype: int64

# %% [markdown]
# ### Removing row from X_data_prep

# %%
X_prep.drop([250], inplace=True)

# %%
X_prep.shape
# Out:
# (250, 13)

# %%
X_prep.tail()
# Out:
#      Gender  Race/Ethnicity  Home_City  Preferred_Langauge  Hobby_Interest  \
# 245       1               1          4                   2               2
# 246       1               0          8                   0               1
# 247       0               2          8                   2               2
# 248       0               1          1                   4               2
# 249       1               2          8                   4               2
#
#      Budget  Fathers_Occupation  Mothers_Occupation  Study_Group  \
# 245       2                   4                   0            1
# 246       0                   1                   0            1
# 247       0                   0                   0            1
# 248       2                   0                   0            3
# 249       2                   0                   0            3
#
#      Degree_Program  Matric Grade  Inter Grade  Campus
# 245               4             0            1       2
# 246               0             1            2       2
# 247               0             1            1       2
# 248               5             1            1       2
# 249               5             3            3       2
