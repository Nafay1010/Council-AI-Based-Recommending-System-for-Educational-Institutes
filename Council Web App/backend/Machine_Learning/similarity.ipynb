# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./university_data.csv')
data.head()
# Out:
#                                Name of University Campus Locations  \
# 0                           University of Karachi          Karachi
# 1  National University of Sciences and Technology        Islamabad
# 2        Lahore University of Management Sciences           Lahore
# 3                         Quaid-i-Azam University        Islamabad
# 4                              Ag Khan University          Karachi
#
#   Campus Size   Programs Offered Acceptance Rate Tuition Fees  \
# 0      Medium        Engineering             30%          Low
# 1      Medium   Computer Science             20%         High
# 2       Small           Business             10%         High
# 3       Large  Political Science             25%          Low
# 4      Medium           Medicine             15%         High
#
#   Type of University Campus Life
# 0             Public      Active
# 1             Public      Active
# 2            Private      Active
# 3             Public      Active
# ...

# %%
# Select relevant features
features = ['Campus Locations', 'Campus Size',
            'Programs Offered', 'Tuition Fees', 'Type of University', 'Campus Life']

# Normalize data
scaler = StandardScaler()
data[features] = scaler.fit_transform(data[features])

# Apply clustering algorithm
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(data[features])
clusters = kmeans.predict(data[features])

# Evaluate results
silhouette_score = metrics.silhouette_score(data[features], clusters)
print('Silhouette score:', silhouette_score)

# Get recommended universities
user_preferences = {'Location': 1, 'Programs': 3,
                    'Facilities': 4, 'Demographics': 2}
recommended_university = model.predict(user_preferences)
similar_universities = data[data['Cluster']
                            == clusters[recommended_university]]
