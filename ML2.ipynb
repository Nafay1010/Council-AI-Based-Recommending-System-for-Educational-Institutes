# %% [markdown]
# # Experiment #02
# #### Since I duplicated the dataset last time, I wanted to check whether if I made changes to the features and then applied KNN, would the accuracy change?

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn import preprocessing

# %%
df1 = pd.read_csv('./cwurData_V4.csv')
df1
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                       7                  9                   1
# 1                       9                 17                   3
# 2                      17                 11                   5
# 3                      10                 24                   4
# 4                       2                 29                   7
# ..                    ...                ...                 ...
# 597                   367                264                  97
# 598                   257                294                 116
# 599                   151                257                  57
# 600                    95                240                 116
# 601                   108                414                 218
#
#      publications  influence  citations  patents   score  institution
# 0               1          1          1        5  100.00            0
# ...

# %%
print(df1['institution'].value_counts())
print(df1.shape)
# Out:
# 0      4
# 69     4
# 67     4
# 66     4
# 65     4
#       ..
# 135    2
# 134    2
# 133    2
# 201    2
# 94     1
# Name: institution, Length: 202, dtype: int64
# (602, 9)

# %% [markdown]
# #### +1 to all features

# %%
df2 = df1
df2 = df2 + 1
df2['institution'] = df2['institution'] - 1
df2
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                       8                 10                   2
# 1                      10                 18                   4
# 2                      18                 12                   6
# 3                      11                 25                   5
# 4                       3                 30                   8
# ..                    ...                ...                 ...
# 597                   368                265                  98
# 598                   258                295                 117
# 599                   152                258                  58
# 600                    96                241                 117
# 601                   109                415                 219
#
#      publications  influence  citations  patents   score  institution
# 0               2          2          2        6  101.00            0
# ...

# %% [markdown]
# #### -1 to all features

# %%
df3 = df1
df3 = df3 - 1
df3['institution'] = df3['institution'] + 1
df3
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                       6                  8                   0
# 1                       8                 16                   2
# 2                      16                 10                   4
# 3                       9                 23                   3
# 4                       1                 28                   6
# ..                    ...                ...                 ...
# 597                   366                263                  96
# 598                   256                293                 115
# 599                   150                256                  56
# 600                    94                239                 115
# 601                   107                413                 217
#
#      publications  influence  citations  patents  score  institution
# 0               0          0          0        4  99.00            0
# ...

# %% [markdown]
# #### +2 to all features

# %%
df4 = df1
df4 = df4 + 2
df4['institution'] = df4['institution'] - 2
df4
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                       9                 11                   3
# 1                      11                 19                   5
# 2                      19                 13                   7
# 3                      12                 26                   6
# 4                       4                 31                   9
# ..                    ...                ...                 ...
# 597                   369                266                  99
# 598                   259                296                 118
# 599                   153                259                  59
# 600                    97                242                 118
# 601                   110                416                 220
#
#      publications  influence  citations  patents   score  institution
# 0               3          3          3        7  102.00            0
# ...

# %% [markdown]
# #### +6 to all features

# %%
df5 = df1
df5 = df5 + 6
df5['institution'] = df5['institution'] - 6
df5
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                      13                 15                   7
# 1                      15                 23                   9
# 2                      23                 17                  11
# 3                      16                 30                  10
# 4                       8                 35                  13
# ..                    ...                ...                 ...
# 597                   373                270                 103
# 598                   263                300                 122
# 599                   157                263                  63
# 600                   101                246                 122
# 601                   114                420                 224
#
#      publications  influence  citations  patents   score  institution
# 0               7          7          7       11  106.00            0
# ...

# %% [markdown]
# #### +5 to all features

# %%
df6 = df1
df6 = df6 + 5
df6['institution'] = df6['institution'] - 5
df6
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                      12                 14                   6
# 1                      14                 22                   8
# 2                      22                 16                  10
# 3                      15                 29                   9
# 4                       7                 34                  12
# ..                    ...                ...                 ...
# 597                   372                269                 102
# 598                   262                299                 121
# 599                   156                262                  62
# 600                   100                245                 121
# 601                   113                419                 223
#
#      publications  influence  citations  patents   score  institution
# 0               6          6          6       10  105.00            0
# ...

# %% [markdown]
# #### +8 to all features

# %%
df7 = df1
df7 = df7 + 8
df7['institution'] = df7['institution'] - 8
df7
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                      15                 17                   9
# 1                      17                 25                  11
# 2                      25                 19                  13
# 3                      18                 32                  12
# 4                      10                 37                  15
# ..                    ...                ...                 ...
# 597                   375                272                 105
# 598                   265                302                 124
# 599                   159                265                  65
# 600                   103                248                 124
# 601                   116                422                 226
#
#      publications  influence  citations  patents   score  institution
# 0               9          9          9       13  108.00            0
# ...

# %% [markdown]
# #### +9 to all features

# %%
df8 = df1
df8 = df8 + 9
df8['institution'] = df8['institution'] - 9
df8
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                      16                 18                  10
# 1                      18                 26                  12
# 2                      26                 20                  14
# 3                      19                 33                  13
# 4                      11                 38                  16
# ..                    ...                ...                 ...
# 597                   376                273                 106
# 598                   266                303                 125
# 599                   160                266                  66
# 600                   104                249                 125
# 601                   117                423                 227
#
#      publications  influence  citations  patents   score  institution
# 0              10         10         10       14  109.00            0
# ...

# %% [markdown]
# #### +3 to all features

# %%
df9 = df1
df9 = df9 + 3
df9['institution'] = df9['institution'] - 3
df9
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                      10                 12                   4
# 1                      12                 20                   6
# 2                      20                 14                   8
# 3                      13                 27                   7
# 4                       5                 32                  10
# ..                    ...                ...                 ...
# 597                   370                267                 100
# 598                   260                297                 119
# 599                   154                260                  60
# 600                    98                243                 119
# 601                   111                417                 221
#
#      publications  influence  citations  patents   score  institution
# 0               4          4          4        8  103.00            0
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], axis=0)
df.shape
# Out:
# (5418, 9)

# %%
Data_V2 = df

# %%
X = Data_V2.iloc[:, 0:8]
y = Data_V2.iloc[:, 8]

MinMaxScaler = preprocessing.MinMaxScaler()
X_data_minmax = MinMaxScaler.fit_transform(X)
# data = pd.DataFrame(X_data_minmax, columns=['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations',  'patents', 'score'])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=0, test_size=0.3)

# %%
X
# Out:
#      quality_of_education  alumni_employment  quality_of_faculty  \
# 0                       7                  9                   1
# 1                       9                 17                   3
# 2                      17                 11                   5
# 3                      10                 24                   4
# 4                       2                 29                   7
# ..                    ...                ...                 ...
# 597                   370                267                 100
# 598                   260                297                 119
# 599                   154                260                  60
# 600                    98                243                 119
# 601                   111                417                 221
#
#      publications  influence  citations  patents   score
# 0               1          1          1        5  100.00
# 1              12          4          4        1   91.67
# ...

# %%
y.value_counts()
# Out:
# 0      36
# 69     36
# 67     36
# 66     36
# 65     36
#        ..
# 135    18
# 134    18
# 133    18
# 201    18
# 94      9
# Name: institution, Length: 202, dtype: int64

# %%
len(y)
# Out:
# 5418

# %%
knn_clf=KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
ypred=knn_clf.predict(X_test) #These are the predicted output values

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 3792
# 3792
# 1626
# 1626

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, ypred)
print("Confusion Matrix: ")
print(result)
result1 = classification_report(y_test, ypred)
print("Classification Report: " ,)
print (result1)
result2 = accuracy_score(y_test,ypred)
print("Accuracy: ",result2)
# Out:
# Confusion Matrix:
# [[12  0  0 ...  0  0  0]
#  [ 0 10  0 ...  0  0  0]
#  [ 0  0 10 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0  4  0]
#  [ 0  0  0 ...  0  0  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        10
#            3       1.00      1.00      1.00        10
#            4       1.00      1.00      1.00        11
#            5       1.00      1.00      1.00         7
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00         9
#            8       1.00      1.00      1.00        12
#            9       1.00      1.00      1.00         9
#           10       1.00      1.00      1.00         8
#           11       1.00      1.00      1.00        10
# ...

# %% [markdown]
# # 99% Accuracy
