# %%
import pandas as pd

# %%
data = pd.read_csv('./CleanData_V2.csv', encoding='unicode_escape')
data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  \
# 0    male        Punjabi   Peshawar               Urdu        Nothing
# 1    male        Pashtun      Kohat             Pashto        Reading
# 2    male        Punjabi  Islamabad            Punjabi         Gaming
# 3  female        Punjabi  Islamabad               Urdu        Nothing
# 4  female          Other     Lahore            English         Sports
#
#    Budget (in millions) Fathers_Occupation Mothers_Occupation Study_Group  \
# 0                     4             Doctor         House Wife          CS
# 1                     5              Engrr         House Wife   Pre-Engrr
# 2                    12               Army             Doctor   Pre-Engrr
# 3                     4              Engrr         House Wife     Pre-Med
# 4                    10             Doctor            Teacher   Pre-Engrr
#
#   Degree_Program  Matric_Marks  Inter_Marks  Year_of_Admission     Campus  \
# 0           BSCS           990          800               2019   Peshawar
# 1           BSEE           900          924               2020  Islamabad
# 2           BSME           930          950               2019     Lahore
# 3        Medical           890          900               2019   Peshawar
# 4           BSEE           900          950               2019     Lahore
#
#    University
# 0  FAST NUCES
# 1     COMSATS
# 2        LUMS
# 3         KMC
# 4        LUMS

# %%
data.shape
# Out:
# (200, 15)

# %%
data['University'].value_counts()
# Out:
# FAST NUCES    20
# COMSATS       20
# LUMS          20
# KMC           20
# UOP           20
# UHS           20
# Aga Khan      20
# NUST          20
# UET           20
# IMsciences    20
# Name: University, dtype: int64

# %% [markdown]
# ### Renaming Column Heading

# %%
data.rename(columns={'Budget (in millions)' : 'Budget'}, inplace=True)
data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  Budget  \
# 0    male        Punjabi   Peshawar               Urdu        Nothing       4
# 1    male        Pashtun      Kohat             Pashto        Reading       5
# 2    male        Punjabi  Islamabad            Punjabi         Gaming      12
# 3  female        Punjabi  Islamabad               Urdu        Nothing       4
# 4  female          Other     Lahore            English         Sports      10
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife          CS           BSCS
# 1              Engrr         House Wife   Pre-Engrr           BSEE
# 2               Army             Doctor   Pre-Engrr           BSME
# 3              Engrr         House Wife     Pre-Med        Medical
# 4             Doctor            Teacher   Pre-Engrr           BSEE
#
#    Matric_Marks  Inter_Marks  Year_of_Admission     Campus  University
# 0           990          800               2019   Peshawar  FAST NUCES
# 1           900          924               2020  Islamabad     COMSATS
# 2           930          950               2019     Lahore        LUMS
# 3           890          900               2019   Peshawar         KMC
# 4           900          950               2019     Lahore        LUMS

# %% [markdown]
# ### Catergorizing Data

# %%
data['Budget'].value_counts()
min_budget = data['Budget'].min()
max_budget = data['Budget'].max()

data['bins_budget'] = pd.cut(x=data['Budget'], bins=[min_budget, 5, 9, max_budget],
                    labels=['Low', 'Medium', 'High',])
data
# Out:
#      Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  \
# 0      male        Punjabi   Peshawar               Urdu        Nothing
# 1      male        Pashtun      Kohat             Pashto        Reading
# 2      male        Punjabi  Islamabad            Punjabi         Gaming
# 3    female        Punjabi  Islamabad               Urdu        Nothing
# 4    female          Other     Lahore            English         Sports
# ..      ...            ...        ...                ...            ...
# 195    male        Punjabi  Islamabad               Urdu        Nothing
# 196    male          Other  Islamabad               Urdu         Gaming
# 197    male          Other  Islamabad            Punjabi         Gaming
# 198    male          Other     Lahore               Urdu         Gaming
# 199    male         Sindhi    Karachi             Sindhi        Writing
#
#      Budget Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0         4             Doctor         House Wife          CS           BSCS
# 1         5              Engrr         House Wife   Pre-Engrr           BSEE
# 2        12               Army             Doctor   Pre-Engrr           BSME
# 3         4              Engrr         House Wife     Pre-Med        Medical
# 4        10             Doctor            Teacher   Pre-Engrr           BSEE
# ..      ...                ...                ...         ...            ...
# 195       4             Doctor         House Wife   Pre-Engrr           BSCE
# 196       6             Doctor         House Wife   Pre-Engrr           BSCE
# 197       7              Engrr             Doctor   Pre-Engrr           BSME
# 198       7             Doctor            Teacher   Pre-Engrr           BSEE
# 199       6             Doctor            Teacher   Pre-Engrr           BSEE
#
#      Matric_Marks  Inter_Marks  Year_of_Admission     Campus  University  \
# 0             990          800               2019   Peshawar  FAST NUCES
# 1             900          924               2020  Islamabad     COMSATS
# 2             930          950               2019     Lahore        LUMS
# 3             890          900               2019   Peshawar         KMC
# 4             900          950               2019     Lahore        LUMS
# ..            ...          ...                ...        ...         ...
# 195           996          997               2019  Islamabad        NUST
# 196           990          999               2019  Islamabad        NUST
# 197          1010          998               2019  Islamabad        NUST
# 198          1009          920               2019  Islamabad        NUST
# 199           997          967               2020  Islamabad        NUST
#
#     bins_budget
# 0           Low
# 1           Low
# 2          High
# 3           Low
# 4          High
# ..          ...
# 195         Low
# 196      Medium
# 197      Medium
# 198      Medium
# 199      Medium
#
# [200 rows x 16 columns]

# %%
min_matric = data['Matric_Marks'].min()
max_matric = data['Matric_Marks'].max()

data['Percentage_Matric'] = (data['Matric_Marks']/1100)*100
data['Percentage_Inter'] = (data['Inter_Marks']/1100)*100


data['Matric_Grade'] = pd.cut(x=data['Percentage_Matric'], bins=[0, 49, 59, 69, 79, 89, 94, 100], labels=['F', 'E', 'D', 'C', 'B', 'A', 'A+'])
data['Inter_Grade'] = pd.cut(x=data['Percentage_Inter'], bins=[0, 49, 59, 69, 79, 89, 94, 100], labels=['F', 'E', 'D', 'C', 'B', 'A', 'A+'])

# %%
data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  Budget  \
# 0    male        Punjabi   Peshawar               Urdu        Nothing       4
# 1    male        Pashtun      Kohat             Pashto        Reading       5
# 2    male        Punjabi  Islamabad            Punjabi         Gaming      12
# 3  female        Punjabi  Islamabad               Urdu        Nothing       4
# 4  female          Other     Lahore            English         Sports      10
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife          CS           BSCS
# 1              Engrr         House Wife   Pre-Engrr           BSEE
# 2               Army             Doctor   Pre-Engrr           BSME
# 3              Engrr         House Wife     Pre-Med        Medical
# 4             Doctor            Teacher   Pre-Engrr           BSEE
#
#    Matric_Marks  Inter_Marks  Year_of_Admission     Campus  University  \
# 0           990          800               2019   Peshawar  FAST NUCES
# 1           900          924               2020  Islamabad     COMSATS
# 2           930          950               2019     Lahore        LUMS
# 3           890          900               2019   Peshawar         KMC
# 4           900          950               2019     Lahore        LUMS
#
#   bins_budget  Percentage_Matric  Percentage_Inter Matric_Grade Inter_Grade
# 0         Low          90.000000         72.727273            A           C
# 1         Low          81.818182         84.000000            B           B
# 2        High          84.545455         86.363636            B           B
# 3         Low          80.909091         81.818182            B           B
# 4        High          81.818182         86.363636            B           B

# %%
data.drop(columns=['Budget', 'Matric_Marks', 'Inter_Marks',
          'Percentage_Matric', 'Percentage_Inter'], inplace=True)
data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  \
# 0    male        Punjabi   Peshawar               Urdu        Nothing
# 1    male        Pashtun      Kohat             Pashto        Reading
# 2    male        Punjabi  Islamabad            Punjabi         Gaming
# 3  female        Punjabi  Islamabad               Urdu        Nothing
# 4  female          Other     Lahore            English         Sports
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife          CS           BSCS
# 1              Engrr         House Wife   Pre-Engrr           BSEE
# 2               Army             Doctor   Pre-Engrr           BSME
# 3              Engrr         House Wife     Pre-Med        Medical
# 4             Doctor            Teacher   Pre-Engrr           BSEE
#
#    Year_of_Admission     Campus  University bins_budget Matric_Grade  \
# 0               2019   Peshawar  FAST NUCES         Low            A
# 1               2020  Islamabad     COMSATS         Low            B
# 2               2019     Lahore        LUMS        High            B
# 3               2019   Peshawar         KMC         Low            B
# 4               2019     Lahore        LUMS        High            B
#
#   Inter_Grade
# 0           C
# 1           B
# 2           B
# 3           B
# 4           B

# %%
data.rename(columns={'bins_budget': "Budget"}, inplace=True)

data = data[['Gender', 'Race/Ethnicity', 'Home_City', 'Preferred_Langauge', 'Hobby_Interest', 'Budget', 'Fathers_Occupation',
            'Mothers_Occupation', 'Study_Group', 'Degree_Program', 'Matric_Grade', 'Inter_Grade', 'Year_of_Admission', 'Campus', 'University']]

data.head()
# Out:
#    Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest Budget  \
# 0    male        Punjabi   Peshawar               Urdu        Nothing    Low
# 1    male        Pashtun      Kohat             Pashto        Reading    Low
# 2    male        Punjabi  Islamabad            Punjabi         Gaming   High
# 3  female        Punjabi  Islamabad               Urdu        Nothing    Low
# 4  female          Other     Lahore            English         Sports   High
#
#   Fathers_Occupation Mothers_Occupation Study_Group Degree_Program  \
# 0             Doctor         House Wife          CS           BSCS
# 1              Engrr         House Wife   Pre-Engrr           BSEE
# 2               Army             Doctor   Pre-Engrr           BSME
# 3              Engrr         House Wife     Pre-Med        Medical
# 4             Doctor            Teacher   Pre-Engrr           BSEE
#
#   Matric_Grade Inter_Grade  Year_of_Admission     Campus  University
# 0            A           C               2019   Peshawar  FAST NUCES
# 1            B           B               2020  Islamabad     COMSATS
# 2            B           B               2019     Lahore        LUMS
# 3            B           B               2019   Peshawar         KMC
# 4            B           B               2019     Lahore        LUMS

# %%
# data.to_csv('./CleanData_V2_Preprocessed.csv', index=False)
