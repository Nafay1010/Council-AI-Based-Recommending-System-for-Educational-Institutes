# %%
import pandas as pd

# %%
df = pd.read_csv("./CleanData_V2 (shuffled).csv")
df.head()
# Out:
#    Gender Race/Ethnicity Home_City Preferred_Langauge Hobby_Interest  \
# 0    male        Pashtun     Kohat               Urdu        Nothing
# 1  female        Punjabi   Sialkot            Punjabi         Gaming
# 2    male        Pashtun   Karachi              Hinko        Writing
# 3    male          Other  Peshawar             Pashto        Nothing
# 4    male        Pashtun   Karachi             Pashto        Nothing
#
#    Budget (in millions) Fathers_Occupation Mothers_Occupation Study_Group  \
# 0                   3.0              Engrr         House Wife    Commerce
# 1                   2.6            Retired         House Wife    Commerce
# 2                   4.0             Doctor         House Wife    Commerce
# 3                   3.0            Retired         House Wife   Pre-Engrr
# 4                   3.0              Engrr         House Wife    Commerce
#
#   Degree_Program  Matric_Marks  Inter_Marks  Year_of_Admission    Campus  \
# ...

# %%
df.shape
# Out:
# (995, 15)

# %%
shuffled_df = df.sample(frac=1).reset_index(drop=True)
shuffled_df.head()
# Out:
#   Gender Race/Ethnicity  Home_City Preferred_Langauge Hobby_Interest  \
# 0   male        Pashtun   Peshawar               Urdu         Gaming
# 1   male        Punjabi  Islamabad               Urdu        Nothing
# 2   male          Other   Peshawar             Pashto        Nothing
# 3   male        Punjabi  Islamabad               Urdu         Gaming
# 4   male        Pashtun   Peshawar             Pashto         Sports
#
#    Budget (in millions) Fathers_Occupation Mothers_Occupation Study_Group  \
# 0                   2.0            Retired             Doctor          CS
# 1                   3.0              Engrr         House Wife     Pre-Med
# 2                   1.0            Retired         House Wife   Pre-Engrr
# 3                   8.0               Army             Doctor    Commerce
# 4                   2.0              Engrr         House Wife   Pre-Engrr
#
#   Degree_Program  Matric_Marks  Inter_Marks  Year_of_Admission    Campus  \
# ...

# %%
shuffled_df.shape
# Out:
# (995, 15)

# %%
shuffled_df.to_csv('./CleanData_V2 (shuffled).csv', index=False)
